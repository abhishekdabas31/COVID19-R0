# %% [markdown]
# <div style="text-align: right">INFO 6105 Data Science Eng Methods and Tools, Spring 20 midterm, Section 6</div>
# <div style="text-align: right">Dino Konstantopoulos, 15 March 2020</div>
#
#
# This notebook is dedicated to Li Wenliang, "*a healthy society should have more than one voice*".
#
# # INFO 6105 Spring 20 Midterm
#
# You have up to two hours, and then a time window of 2 hours to submit. Earlier submissions have an advantage over later ones, unless later ones have better results. Since we don't have class on Tuesday, you may also continue to work on this midterm as a homework for bonus points, due before class next Thursday.
#
# You are going to model the Coronavirus!
#
# <br />
# <center>
# <img src="https://www.paho.org/hq/images/stories/2020/coronavirus-6-1400x592.jpg" width=600 />
# </center>

# %% [markdown]
# # Data from China
#
# This [website](https://github.com/BlankerL/DXY-COVID-19-Data) is a result of good citizenship: People posting real data that can help other people learn from mistakes and fare better.
#
# Download this data, import `DXYArea.csv` as a pandas dataframe, and plot some interesting plots.

# %%
import pandas as pd
df = pd.read_csv("DXYArea.csv")

# %%
data = pd.DataFrame(df)
print(len(data))
data
# Out:
# 70354
#       provinceName provinceEnglishName  province_zipCode cityName  \
# 0              甘肃省               Gansu            620000   境外输入人员
# 1              甘肃省               Gansu            620000       兰州
# 2              甘肃省               Gansu            620000       天水
# 3              甘肃省               Gansu            620000       平凉
# 4              甘肃省               Gansu            620000       定西
# ...            ...                 ...               ...      ...
# 70349          云南省              Yunnan            530000       昆明
# 70350          山西省              Shanxi            140000       太原
# 70351          吉林省               Jilin            220000       长春
# 70352          河北省               Hebei            130000      石家庄
# 70353      宁夏回族自治区             Ningxia            640000       银川
#
#       cityEnglishName  city_zipCode  province_confirmedCount  \
# 0                 NaN           0.0                      133
# 1             Lanzhou      620100.0                      133
# 2            Tianshui      620500.0                      133
# 3           Pingliang      620800.0                      133
# 4              Dingxi      621100.0                      133
# ...               ...           ...                      ...
# 70349         Kunming      530100.0                        2
# 70350         Taiyuan      140100.0                        1
# 70351       Changchun      220100.0                        1
# 70352    Shijiazhuang      130100.0                        1
# 70353        Yinchuan      640100.0                        1
#
#        province_suspectedCount  province_curedCount  province_deadCount  \
# 0                            0                   91                   2
# 1                            0                   91                   2
# 2                            0                   91                   2
# 3                            0                   91                   2
# 4                            0                   91                   2
# ...                        ...                  ...                 ...
# 70349                        0                    0                   0
# 70350                        0                    0                   0
# 70351                        0                    0                   0
# 70352                        0                    0                   1
# 70353                        0                    0                   0
#
#        city_confirmedCount  city_suspectedCount  city_curedCount  \
# 0                       42                    0                2
# 1                       36                    0               34
# 2                       12                    0               12
# 3                        9                    0                9
# 4                        9                    0                9
# ...                    ...                  ...              ...
# 70349                    2                    0                0
# 70350                    1                    0                0
# 70351                    1                    0                0
# 70352                    1                    0                0
# 70353                    1                    0                0
#
#        city_deadCount               updateTime
# 0                   0  2020-03-15 21:41:38.179
# 1                   2  2020-03-15 21:41:38.179
# 2                   0  2020-03-15 21:41:38.179
# 3                   0  2020-03-15 21:41:38.179
# 4                   0  2020-03-15 21:41:38.179
# ...               ...                      ...
# 70349               0  2020-01-24 03:50:31.353
# 70350               0  2020-01-24 03:50:31.353
# 70351               0  2020-01-24 03:50:31.353
# 70352               0  2020-01-24 03:50:31.353
# 70353               0  2020-01-24 03:50:31.353
#
# [70354 rows x 15 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

plt.plot(data.province_confirmedCount)
plt.plot(data.province_deadCount)

plt.title("Covid19 in China, diagnosed/fatalities")
plt.xlabel("diagnosed/fatalities")
plt.ylabel("cities")
plt.grid(True)

# %% [markdown]
# Now drop the columns 'province_suspectedCount', 'city_suspectedCount', 'province_zipCode', 'city_zipCode', and display the dataframe.

# %%
data=data.drop(['province_suspectedCount', 'city_suspectedCount' , 'province_zipCode', 'city_zipCode'],axis=1)
data
# Out:
#       provinceName provinceEnglishName cityName cityEnglishName  \
# 0              甘肃省               Gansu   境外输入人员             NaN
# 1              甘肃省               Gansu       兰州         Lanzhou
# 2              甘肃省               Gansu       天水        Tianshui
# 3              甘肃省               Gansu       平凉       Pingliang
# 4              甘肃省               Gansu       定西          Dingxi
# ...            ...                 ...      ...             ...
# 70349          云南省              Yunnan       昆明         Kunming
# 70350          山西省              Shanxi       太原         Taiyuan
# 70351          吉林省               Jilin       长春       Changchun
# 70352          河北省               Hebei      石家庄    Shijiazhuang
# 70353      宁夏回族自治区             Ningxia       银川        Yinchuan
#
#        province_confirmedCount  province_curedCount  province_deadCount  \
# 0                          133                   91                   2
# 1                          133                   91                   2
# 2                          133                   91                   2
# 3                          133                   91                   2
# 4                          133                   91                   2
# ...                        ...                  ...                 ...
# 70349                        2                    0                   0
# 70350                        1                    0                   0
# 70351                        1                    0                   0
# 70352                        1                    0                   1
# 70353                        1                    0                   0
#
#        city_confirmedCount  city_curedCount  city_deadCount  \
# 0                       42                2               0
# 1                       36               34               2
# 2                       12               12               0
# 3                        9                9               0
# 4                        9                9               0
# ...                    ...              ...             ...
# 70349                    2                0               0
# 70350                    1                0               0
# 70351                    1                0               0
# 70352                    1                0               0
# 70353                    1                0               0
#
#                     updateTime
# 0      2020-03-15 21:41:38.179
# 1      2020-03-15 21:41:38.179
# 2      2020-03-15 21:41:38.179
# 3      2020-03-15 21:41:38.179
# 4      2020-03-15 21:41:38.179
# ...                        ...
# 70349  2020-01-24 03:50:31.353
# 70350  2020-01-24 03:50:31.353
# 70351  2020-01-24 03:50:31.353
# 70352  2020-01-24 03:50:31.353
# 70353  2020-01-24 03:50:31.353
#
# [70354 rows x 11 columns]

# %% [markdown]
# How many rows in the dataframe?

# %%
len(data)
# Out:
# 70354

# %%
# len(covid19_china)

# %% [markdown]
# Do some data healing to remove all NaN entries.

# %%
data.isna().any()
# Out:
# provinceName               False
# provinceEnglishName        False
# cityName                   False
# cityEnglishName             True
# province_confirmedCount    False
# province_curedCount        False
# province_deadCount         False
# city_confirmedCount        False
# city_curedCount            False
# city_deadCount             False
# updateTime                 False
# dtype: bool

# %% [markdown]
# # so the cityEnglishName has NAN values

# %%
df[df.isna().any(axis=1)]
# Out:
#       provinceName provinceEnglishName  province_zipCode cityName  \
# 0              甘肃省               Gansu            620000   境外输入人员
# 177            甘肃省               Gansu            620000   境外输入人员
# 260            北京市             Beijing            110000   境外输入人员
# 304            甘肃省               Gansu            620000   境外输入人员
# 316            上海市            Shanghai            310000   境外输入人员
# ...            ...                 ...               ...      ...
# 70291          北京市             Beijing            110000       朝阳
# 70292          北京市             Beijing            110000      石景山
# 70293          北京市             Beijing            110000     不明地区
# 70327          河南省               Henan            410000       巩义
# 70332          海南省              Hainan            460000      临高县
#
#       cityEnglishName  city_zipCode  province_confirmedCount  \
# 0                 NaN           0.0                      133
# 177               NaN           0.0                      132
# 260               NaN           0.0                      442
# 304               NaN           0.0                      132
# 316               NaN           0.0                      353
# ...               ...           ...                      ...
# 70291             NaN           NaN                       22
# 70292             NaN           NaN                       22
# 70293             NaN           NaN                       22
# 70327             NaN           NaN                        5
# 70332             NaN           NaN                        5
#
#        province_suspectedCount  province_curedCount  province_deadCount  \
# 0                            0                   91                   2
# 177                          0                   91                   2
# 260                          0                  353                   8
# 304                          0                   89                   2
# 316                          0                  324                   3
# ...                        ...                  ...                 ...
# 70291                        0                    0                   0
# 70292                        0                    0                   0
# 70293                        0                    0                   0
# 70327                        0                    0                   0
# 70332                        0                    0                   0
#
#        city_confirmedCount  city_suspectedCount  city_curedCount  \
# 0                       42                    0                2
# 177                     41                    0                2
# 260                     27                    0                0
# 304                     41                    0                0
# 316                     15                    0                0
# ...                    ...                  ...              ...
# 70291                    1                    0                0
# 70292                    1                    0                0
# 70293                    8                    0                0
# 70327                    1                    0                0
# 70332                    1                    0                0
#
#        city_deadCount               updateTime
# 0                   0  2020-03-15 21:41:38.179
# 177                 0  2020-03-15 10:03:21.082
# 260                 0  2020-03-15 09:11:28.429
# 304                 0  2020-03-15 07:57:42.402
# 316                 0  2020-03-15 07:53:21.051
# ...               ...                      ...
# 70291               0  2020-01-24 03:50:31.353
# 70292               0  2020-01-24 03:50:31.353
# 70293               0  2020-01-24 03:50:31.353
# 70327               0  2020-01-24 03:50:31.353
# 70332               0  2020-01-24 03:50:31.353
#
# [1889 rows x 15 columns]

# %%
total = data.isnull().sum().sort_values(ascending=False)
percent = (data.isnull().sum()/data.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data
# Out:
#                          Total   Percent
# cityEnglishName           1651  0.023467
# updateTime                   0  0.000000
# city_deadCount               0  0.000000
# city_curedCount              0  0.000000
# city_confirmedCount          0  0.000000
# province_deadCount           0  0.000000
# province_curedCount          0  0.000000
# province_confirmedCount      0  0.000000
# cityName                     0  0.000000
# provinceEnglishName          0  0.000000
# provinceName                 0  0.000000

# %% [markdown]
# the data with NAN values is small(0.02%) so we can drop the rows

# %%
data= data.dropna()
data
# Out:
#       provinceName provinceEnglishName cityName cityEnglishName  \
# 1              甘肃省               Gansu       兰州         Lanzhou
# 2              甘肃省               Gansu       天水        Tianshui
# 3              甘肃省               Gansu       平凉       Pingliang
# 4              甘肃省               Gansu       定西          Dingxi
# 5              甘肃省               Gansu       甘南          Gannan
# ...            ...                 ...      ...             ...
# 70349          云南省              Yunnan       昆明         Kunming
# 70350          山西省              Shanxi       太原         Taiyuan
# 70351          吉林省               Jilin       长春       Changchun
# 70352          河北省               Hebei      石家庄    Shijiazhuang
# 70353      宁夏回族自治区             Ningxia       银川        Yinchuan
#
#        province_confirmedCount  province_curedCount  province_deadCount  \
# 1                          133                   91                   2
# 2                          133                   91                   2
# 3                          133                   91                   2
# 4                          133                   91                   2
# 5                          133                   91                   2
# ...                        ...                  ...                 ...
# 70349                        2                    0                   0
# 70350                        1                    0                   0
# 70351                        1                    0                   0
# 70352                        1                    0                   1
# 70353                        1                    0                   0
#
#        city_confirmedCount  city_curedCount  city_deadCount  \
# 1                       36               34               2
# 2                       12               12               0
# 3                        9                9               0
# 4                        9                9               0
# 5                        8                8               0
# ...                    ...              ...             ...
# 70349                    2                0               0
# 70350                    1                0               0
# 70351                    1                0               0
# 70352                    1                0               0
# 70353                    1                0               0
#
#                     updateTime
# 1      2020-03-15 21:41:38.179
# 2      2020-03-15 21:41:38.179
# 3      2020-03-15 21:41:38.179
# 4      2020-03-15 21:41:38.179
# 5      2020-03-15 21:41:38.179
# ...                        ...
# 70349  2020-01-24 03:50:31.353
# 70350  2020-01-24 03:50:31.353
# 70351  2020-01-24 03:50:31.353
# 70352  2020-01-24 03:50:31.353
# 70353  2020-01-24 03:50:31.353
#
# [68703 rows x 11 columns]

# %%
data.isna().any()
# Out:
# provinceName               False
# provinceEnglishName        False
# cityName                   False
# cityEnglishName            False
# province_confirmedCount    False
# province_curedCount        False
# province_deadCount         False
# city_confirmedCount        False
# city_curedCount            False
# city_deadCount             False
# updateTime                 False
# dtype: bool

# %% [markdown]
# What's the new number of rows?

# %% [markdown]
# 68703 rows

# %% [markdown]
# What are the city names?

# %%
data.cityEnglishName.values
# Out:
# array(['Lanzhou', 'Tianshui', 'Pingliang', ..., 'Changchun',
#        'Shijiazhuang', 'Yinchuan'], dtype=object)

# %% [markdown]
# How many rows refer to the city of Wuhan?

# %%
len(data[data["cityEnglishName"]=="Wuhan"])
# Out:
# 366

# %% [markdown]
# 366 rows

# %% [markdown]
# Print the dataframe with rows that only refer to Wuhan.

# %%
wuhan_data= data[data["cityEnglishName"]=="Wuhan"]
wuhan_data= wuhan_data.drop_duplicates(subset=['updateTime'])
wuhan_data
# Out:
#       provinceName provinceEnglishName cityName cityEnglishName  \
# 32             湖北省               Hubei       武汉           Wuhan
# 274            湖北省               Hubei       武汉           Wuhan
# 388            湖北省               Hubei       武汉           Wuhan
# 405            湖北省               Hubei       武汉           Wuhan
# 447            湖北省               Hubei       武汉           Wuhan
# ...            ...                 ...      ...             ...
# 69794          湖北省               Hubei       武汉           Wuhan
# 70050          湖北省               Hubei       武汉           Wuhan
# 70058          湖北省               Hubei       武汉           Wuhan
# 70064          湖北省               Hubei       武汉           Wuhan
# 70068          湖北省               Hubei       武汉           Wuhan
#
#        province_confirmedCount  province_curedCount  province_deadCount  \
# 32                       67794                54288                3085
# 274                      67794                54278                3085
# 388                      67790                52960                3075
# 405                      67790                52962                3075
# 447                      67790                52959                3075
# ...                        ...                  ...                 ...
# 69794                      549                    0                   0
# 70050                      549                    0                   0
# 70058                      549                    0                   0
# 70064                      549                    0                   0
# 70068                      549                    0                   0
#
#        city_confirmedCount  city_curedCount  city_deadCount  \
# 32                   49999            37642            2456
# 274                  49995            36465            2446
# 388                  49995            36465            2446
# 405                  49995            36467            2446
# 447                  49995            36467            2446
# ...                    ...              ...             ...
# 69794                  495                0               0
# 70050                  495                0               0
# 70058                  495                0               0
# 70064                  495                0               0
# 70068                  495                0               0
#
#                     updateTime
# 32     2020-03-15 18:07:03.272
# 274    2020-03-15 08:49:13.790
# 388    2020-03-14 17:58:00.660
# 405    2020-03-14 17:49:06.329
# 447    2020-03-14 16:54:11.267
# ...                        ...
# 69794  2020-01-24 11:49:48.584
# 70050  2020-01-24 09:50:40.357
# 70058  2020-01-24 09:49:39.772
# 70064  2020-01-24 09:48:39.253
# 70068  2020-01-24 09:47:38.698
#
# [365 rows x 11 columns]

# %% [markdown]
# Sort by 'updateTime'.

# %%
wuhan_data=wuhan_data.sort_values(['updateTime'])
wuhan_data
# Out:
#       provinceName provinceEnglishName cityName cityEnglishName  \
# 70068          湖北省               Hubei       武汉           Wuhan
# 70064          湖北省               Hubei       武汉           Wuhan
# 70058          湖北省               Hubei       武汉           Wuhan
# 70050          湖北省               Hubei       武汉           Wuhan
# 69794          湖北省               Hubei       武汉           Wuhan
# ...            ...                 ...      ...             ...
# 447            湖北省               Hubei       武汉           Wuhan
# 405            湖北省               Hubei       武汉           Wuhan
# 388            湖北省               Hubei       武汉           Wuhan
# 274            湖北省               Hubei       武汉           Wuhan
# 32             湖北省               Hubei       武汉           Wuhan
#
#        province_confirmedCount  province_curedCount  province_deadCount  \
# 70068                      549                    0                   0
# 70064                      549                    0                   0
# 70058                      549                    0                   0
# 70050                      549                    0                   0
# 69794                      549                    0                   0
# ...                        ...                  ...                 ...
# 447                      67790                52959                3075
# 405                      67790                52962                3075
# 388                      67790                52960                3075
# 274                      67794                54278                3085
# 32                       67794                54288                3085
#
#        city_confirmedCount  city_curedCount  city_deadCount  \
# 70068                  495                0               0
# 70064                  495                0               0
# 70058                  495                0               0
# 70050                  495                0               0
# 69794                  495                0               0
# ...                    ...              ...             ...
# 447                  49995            36467            2446
# 405                  49995            36467            2446
# 388                  49995            36465            2446
# 274                  49995            36465            2446
# 32                   49999            37642            2456
#
#                     updateTime
# 70068  2020-01-24 09:47:38.698
# 70064  2020-01-24 09:48:39.253
# 70058  2020-01-24 09:49:39.772
# 70050  2020-01-24 09:50:40.357
# 69794  2020-01-24 11:49:48.584
# ...                        ...
# 447    2020-03-14 16:54:11.267
# 405    2020-03-14 17:49:06.329
# 388    2020-03-14 17:58:00.660
# 274    2020-03-15 08:49:13.790
# 32     2020-03-15 18:07:03.272
#
# [365 rows x 11 columns]

# %% [markdown]
# Reset the dataframe's index to be 'updateTime'

# %%
wuhan_data = wuhan_data.set_index('updateTime')
wuhan_data
# Out:
#                         provinceName provinceEnglishName cityName  \
# updateTime
# 2020-01-24 09:47:38.698          湖北省               Hubei       武汉
# 2020-01-24 09:48:39.253          湖北省               Hubei       武汉
# 2020-01-24 09:49:39.772          湖北省               Hubei       武汉
# 2020-01-24 09:50:40.357          湖北省               Hubei       武汉
# 2020-01-24 11:49:48.584          湖北省               Hubei       武汉
# ...                              ...                 ...      ...
# 2020-03-14 16:54:11.267          湖北省               Hubei       武汉
# 2020-03-14 17:49:06.329          湖北省               Hubei       武汉
# 2020-03-14 17:58:00.660          湖北省               Hubei       武汉
# 2020-03-15 08:49:13.790          湖北省               Hubei       武汉
# 2020-03-15 18:07:03.272          湖北省               Hubei       武汉
#
#                         cityEnglishName  province_confirmedCount  \
# updateTime
# 2020-01-24 09:47:38.698           Wuhan                      549
# 2020-01-24 09:48:39.253           Wuhan                      549
# 2020-01-24 09:49:39.772           Wuhan                      549
# 2020-01-24 09:50:40.357           Wuhan                      549
# 2020-01-24 11:49:48.584           Wuhan                      549
# ...                                 ...                      ...
# 2020-03-14 16:54:11.267           Wuhan                    67790
# 2020-03-14 17:49:06.329           Wuhan                    67790
# 2020-03-14 17:58:00.660           Wuhan                    67790
# 2020-03-15 08:49:13.790           Wuhan                    67794
# 2020-03-15 18:07:03.272           Wuhan                    67794
#
#                          province_curedCount  province_deadCount  \
# updateTime
# 2020-01-24 09:47:38.698                    0                   0
# 2020-01-24 09:48:39.253                    0                   0
# 2020-01-24 09:49:39.772                    0                   0
# 2020-01-24 09:50:40.357                    0                   0
# 2020-01-24 11:49:48.584                    0                   0
# ...                                      ...                 ...
# 2020-03-14 16:54:11.267                52959                3075
# 2020-03-14 17:49:06.329                52962                3075
# 2020-03-14 17:58:00.660                52960                3075
# 2020-03-15 08:49:13.790                54278                3085
# 2020-03-15 18:07:03.272                54288                3085
#
#                          city_confirmedCount  city_curedCount  city_deadCount
# updateTime
# 2020-01-24 09:47:38.698                  495                0               0
# 2020-01-24 09:48:39.253                  495                0               0
# 2020-01-24 09:49:39.772                  495                0               0
# 2020-01-24 09:50:40.357                  495                0               0
# 2020-01-24 11:49:48.584                  495                0               0
# ...                                      ...              ...             ...
# 2020-03-14 16:54:11.267                49995            36467            2446
# 2020-03-14 17:49:06.329                49995            36467            2446
# 2020-03-14 17:58:00.660                49995            36465            2446
# 2020-03-15 08:49:13.790                49995            36465            2446
# 2020-03-15 18:07:03.272                49999            37642            2456
#
# [365 rows x 10 columns]

# %% [markdown]
# Plot 'confirmedCount', 'curedCount', and 'deadCount' for the city of Wuhan.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
wuhan_data["city_confirmedCount"].plot()
wuhan_data["city_curedCount"].plot()
wuhan_data["city_deadCount"].plot()
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Do the same for the province of Hubei (including resetting the index).

# %%
Hubei_data= data[data["provinceEnglishName"]=="Hubei"]
Hubei_data= Hubei_data.drop_duplicates(subset=['updateTime'])
Hubei_data= Hubei_data.sort_values(by=['updateTime'])
Hubei_data = Hubei_data.set_index('updateTime')
Hubei_data
# Out:
#                         provinceName provinceEnglishName cityName  \
# updateTime
# 2020-01-24 09:47:38.698          湖北省               Hubei       武汉
# 2020-01-24 09:48:39.253          湖北省               Hubei       武汉
# 2020-01-24 09:49:39.772          湖北省               Hubei       武汉
# 2020-01-24 09:50:40.357          湖北省               Hubei       武汉
# 2020-01-24 11:49:48.584          湖北省               Hubei       武汉
# ...                              ...                 ...      ...
# 2020-03-14 16:54:11.267          湖北省               Hubei       武汉
# 2020-03-14 17:49:06.329          湖北省               Hubei       武汉
# 2020-03-14 17:58:00.660          湖北省               Hubei       武汉
# 2020-03-15 08:49:13.790          湖北省               Hubei       武汉
# 2020-03-15 18:07:03.272          湖北省               Hubei       武汉
#
#                         cityEnglishName  province_confirmedCount  \
# updateTime
# 2020-01-24 09:47:38.698           Wuhan                      549
# 2020-01-24 09:48:39.253           Wuhan                      549
# 2020-01-24 09:49:39.772           Wuhan                      549
# 2020-01-24 09:50:40.357           Wuhan                      549
# 2020-01-24 11:49:48.584           Wuhan                      549
# ...                                 ...                      ...
# 2020-03-14 16:54:11.267           Wuhan                    67790
# 2020-03-14 17:49:06.329           Wuhan                    67790
# 2020-03-14 17:58:00.660           Wuhan                    67790
# 2020-03-15 08:49:13.790           Wuhan                    67794
# 2020-03-15 18:07:03.272           Wuhan                    67794
#
#                          province_curedCount  province_deadCount  \
# updateTime
# 2020-01-24 09:47:38.698                    0                   0
# 2020-01-24 09:48:39.253                    0                   0
# 2020-01-24 09:49:39.772                    0                   0
# 2020-01-24 09:50:40.357                    0                   0
# 2020-01-24 11:49:48.584                    0                   0
# ...                                      ...                 ...
# 2020-03-14 16:54:11.267                52959                3075
# 2020-03-14 17:49:06.329                52962                3075
# 2020-03-14 17:58:00.660                52960                3075
# 2020-03-15 08:49:13.790                54278                3085
# 2020-03-15 18:07:03.272                54288                3085
#
#                          city_confirmedCount  city_curedCount  city_deadCount
# updateTime
# 2020-01-24 09:47:38.698                  495                0               0
# 2020-01-24 09:48:39.253                  495                0               0
# 2020-01-24 09:49:39.772                  495                0               0
# 2020-01-24 09:50:40.357                  495                0               0
# 2020-01-24 11:49:48.584                  495                0               0
# ...                                      ...              ...             ...
# 2020-03-14 16:54:11.267                49995            36467            2446
# 2020-03-14 17:49:06.329                49995            36467            2446
# 2020-03-14 17:58:00.660                49995            36465            2446
# 2020-03-15 08:49:13.790                49995            36465            2446
# 2020-03-15 18:07:03.272                49999            37642            2456
#
# [365 rows x 10 columns]

# %% [markdown]
# Plot the same plot for the province of Hubei.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(Hubei_data.province_confirmedCount)
plt.plot(Hubei_data.province_curedCount)
plt.plot(Hubei_data.province_deadCount)
plt.show()

# %% [markdown]
# And now for Shanghai.

# %%
Shanghai_data= data[data["provinceEnglishName"]=="Shanghai"]
Shanghai_data= Shanghai_data.drop_duplicates(subset=['updateTime'])
Shanghai_data= Shanghai_data.sort_values(by=['updateTime'])
Shanghai_data = Shanghai_data.set_index('updateTime')
Shanghai_data
# Out:
#                         provinceName provinceEnglishName cityName  \
# updateTime
# 2020-01-27 10:40:52.129          上海市            Shanghai     浦东新区
# 2020-01-27 10:41:52.755          上海市            Shanghai     浦东新区
# 2020-01-27 10:42:53.420          上海市            Shanghai     浦东新区
# 2020-01-27 10:43:54.014          上海市            Shanghai   外地来沪人员
# 2020-01-27 15:28:25.872          上海市            Shanghai   外地来沪人员
# ...                              ...                 ...      ...
# 2020-03-13 16:51:09.499          上海市            Shanghai   外地来沪人员
# 2020-03-13 18:03:52.065          上海市            Shanghai   外地来沪人员
# 2020-03-14 09:48:04.914          上海市            Shanghai   外地来沪人员
# 2020-03-14 15:07:11.495          上海市            Shanghai   外地来沪人员
# 2020-03-15 07:53:21.051          上海市            Shanghai   外地来沪人员
#
#                                   cityEnglishName  province_confirmedCount  \
# updateTime
# 2020-01-27 10:40:52.129           Pudong District                       53
# 2020-01-27 10:41:52.755           Pudong District                       53
# 2020-01-27 10:42:53.420           Pudong District                       53
# 2020-01-27 10:43:54.014  People from other cities                       53
# 2020-01-27 15:28:25.872  People from other cities                       53
# ...                                           ...                      ...
# 2020-03-13 16:51:09.499  People from other cities                      346
# 2020-03-13 18:03:52.065  People from other cities                      346
# 2020-03-14 09:48:04.914  People from other cities                      350
# 2020-03-14 15:07:11.495  People from other cities                      352
# 2020-03-15 07:53:21.051  People from other cities                      353
#
#                          province_curedCount  province_deadCount  \
# updateTime
# 2020-01-27 10:40:52.129                    1                   1
# 2020-01-27 10:41:52.755                    1                   1
# 2020-01-27 10:42:53.420                    1                   1
# 2020-01-27 10:43:54.014                    1                   1
# 2020-01-27 15:28:25.872                    3                   1
# ...                                      ...                 ...
# 2020-03-13 16:51:09.499                  323                   3
# 2020-03-13 18:03:52.065                  324                   3
# 2020-03-14 09:48:04.914                  324                   3
# 2020-03-14 15:07:11.495                  324                   3
# 2020-03-15 07:53:21.051                  324                   3
#
#                          city_confirmedCount  city_curedCount  city_deadCount
# updateTime
# 2020-01-27 10:40:52.129                    7                0               0
# 2020-01-27 10:41:52.755                    7                0               0
# 2020-01-27 10:42:53.420                    7                0               0
# 2020-01-27 10:43:54.014                   23                0               0
# 2020-01-27 15:28:25.872                   23                2               0
# ...                                      ...              ...             ...
# 2020-03-13 16:51:09.499                  111              106               1
# 2020-03-13 18:03:52.065                  111              106               1
# 2020-03-14 09:48:04.914                  111              106               1
# 2020-03-14 15:07:11.495                  111              106               1
# 2020-03-15 07:53:21.051                  111              106               1
#
# [162 rows x 10 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(Shanghai_data.province_confirmedCount)
plt.plot(Shanghai_data.province_curedCount)
plt.plot(Shanghai_data.province_deadCount)

plt.show()

# %% [markdown]
# And now for Beijing.

# %%
Beijing_data = data[data["provinceEnglishName"]=="Beijing"]
Beijing_data = Beijing_data.sort_values(by=['updateTime'])
Beijing_data = Beijing_data.set_index('updateTime')
Beijing_data
# Out:
#                         provinceName provinceEnglishName cityName  \
# updateTime
# 2020-01-24 16:06:14.033          北京市             Beijing   外地来京人员
# 2020-01-24 16:07:14.755          北京市             Beijing   外地来京人员
# 2020-01-24 19:45:37.021          北京市             Beijing   外地来京人员
# 2020-01-24 19:46:37.661          北京市             Beijing   外地来京人员
# 2020-01-24 19:49:39.502          北京市             Beijing   外地来京人员
# ...                              ...                 ...      ...
# 2020-03-15 09:11:28.429          北京市             Beijing     门头沟区
# 2020-03-15 09:11:28.429          北京市             Beijing      延庆区
# 2020-03-15 09:11:28.429          北京市             Beijing    待明确地区
# 2020-03-15 09:11:28.429          北京市             Beijing      房山区
# 2020-03-15 09:11:28.429          北京市             Beijing      朝阳区
#
#                                   cityEnglishName  province_confirmedCount  \
# updateTime
# 2020-01-24 16:06:14.033  People from other cities                       26
# 2020-01-24 16:07:14.755  People from other cities                       29
# 2020-01-24 19:45:37.021  People from other cities                       29
# 2020-01-24 19:46:37.661  People from other cities                       29
# 2020-01-24 19:49:39.502  People from other cities                       34
# ...                                           ...                      ...
# 2020-03-15 09:11:28.429        Mentougou District                      442
# 2020-03-15 09:11:28.429          Yanqing District                      442
# 2020-03-15 09:11:28.429          Area not defined                      442
# 2020-03-15 09:11:28.429         Fangshan District                      442
# 2020-03-15 09:11:28.429         Chaoyang District                      442
#
#                          province_curedCount  province_deadCount  \
# updateTime
# 2020-01-24 16:06:14.033                    1                   0
# 2020-01-24 16:07:14.755                    1                   0
# 2020-01-24 19:45:37.021                    1                   0
# 2020-01-24 19:46:37.661                    1                   0
# 2020-01-24 19:49:39.502                    1                   0
# ...                                      ...                 ...
# 2020-03-15 09:11:28.429                  353                   8
# 2020-03-15 09:11:28.429                  353                   8
# 2020-03-15 09:11:28.429                  353                   8
# 2020-03-15 09:11:28.429                  353                   8
# 2020-03-15 09:11:28.429                  353                   8
#
#                          city_confirmedCount  city_curedCount  city_deadCount
# updateTime
# 2020-01-24 16:06:14.033                    9                0               0
# 2020-01-24 16:07:14.755                    9                0               0
# 2020-01-24 19:45:37.021                    9                0               0
# 2020-01-24 19:46:37.661                   10                0               0
# 2020-01-24 19:49:39.502                   10                0               0
# ...                                      ...              ...             ...
# 2020-03-15 09:11:28.429                    3                2               0
# 2020-03-15 09:11:28.429                    1                0               0
# 2020-03-15 09:11:28.429                    0              314               8
# 2020-03-15 09:11:28.429                   16                3               0
# 2020-03-15 09:11:28.429                   72                0               0
#
# [1498 rows x 10 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(Beijing_data.province_confirmedCount)
plt.plot(Beijing_data.province_curedCount)
plt.plot(Beijing_data.province_deadCount)

# %% [markdown]
# And there are a lot more cities in the data!

# %%
cities =[ ', '.join([str(x) for x in data.cityEnglishName.values])]
cities
# Out:
# ["Lanzhou, Tianshui, Pingliang, Dingxi, Gannan, Baiyin, Longnan, Qingyang, Linxia, Zhangye, Jinchang, Shenzhen, Guangzhou, Foshan, Zhongshan, Dongguan, Shantou, Zhuhai, Huizhou, Jiangmen, Zhanjiang, Zhaoqing, Meizhou, Yangjiang, Maoming, Qingyuan, Shaoguan, Jieyang, Shanwei, Chaozhou, Heyuan, Wuhan, Xiaogan, Ezhou, Suizhou, Jingzhou, Huanggang, Shiyan, Yichang, Huangshi, Xiantao, Jingmen, Xiangyang, Qianjiang, Tianmen, Enshi Tujia and Miao Autonomous Prefecture, Xianning, Shennongjia, Shenzhen, Guangzhou, Zhongshan, Foshan, Dongguan, Shantou, Zhuhai, Huizhou, Jiangmen, Zhanjiang, Zhaoqing, Meizhou, Yangjiang, Maoming, Qingyuan, Shaoguan, Jieyang, Shanwei, Chaozhou, Heyuan, Chengdu, Garzê Tibetan Autonomous Prefecture, Dazhou, Nanchong, Guang'an, Luzhou, Bazhong, Mianyang, Neijiang, Deyang, Suining, Panzhihua, Liangshan Yi Autonomous Prefecture, Yibin, Zigong, Meishan, Ya'an, Guangyuan, Ziyang, Leshan, Ngawa Tibetan and Qiang Autonomous Prefecture, Shenzhen, Guangzhou, Zhongshan, Foshan, Dongguan, Shantou, Zhuhai, Huizhou, Jiangmen, Zhanjiang, Zhaoqing, Meizhou, Yangjiang, Maoming, Qingyuan, Shaoguan, Jieyang, Shanwei, Chaozhou, Heyuan, Baodi District, Hedong District, Hebei District, Beichen District, Nankai District, Heping District, People from other cities, Dongli District, Ninghe District, Hexi District, Xiqing District, Binhai New Area, Wuqing District, Hongqiao District, Jinnan District, Dandong, Shenyang, Huludao, Dalian, Chaoyang, Jinzhou, Panjin, Fuxin, Tieling, Anshan, Benxi, Liaoyang, Yingkou, Wanzhou District, Jiangbei District, Yunyang County, Hechuan District, Qijiang District, Changshou District, Fengjie County, Jiulongpo District, Kaizhou District, Zhong County, Yuzhong District, Dianjiang County, Tongnan District, Yubei District, Liangjiang New Area, Nan'an District, Shizhu Tujia Autonomous County, Dazu District, Wuxi County, Tongliang District, Fengdu County, Wushan County, Shapingba District, Bishan District, Rongchang District, Dadukou District, Banan District, Fuling District, Yongchuan District, Jiangjin District, Liangping District, Chongqing High-tech Zone, Qianjiang Tujia and Miao Autonomous County, Chengkou County, Pengshui Miao and Tujia Autonomous County, Wulong District, Xiushan Tujia and Miao Autonomous County, Youyang Tujia and Miao Autonomous County, Wansheng District, Lanzhou, Tianshui, Pingliang, Dingxi, Gannan, Baiyin, Longnan, Qingyang, Linxia, Zhangye, Jinchang, Nanjing, Suzhou, Xuzhou, Huainan, Wuxi, Changzhou, Lianyungang, Nantong, Taizhou, Yancheng, Yangzhou, Suqian, Zhenjiang, Chengdu, Garzê Tibetan Autonomous Prefecture, Dazhou, Nanchong, Guang'an, Luzhou, Bazhong, Mianyang, Neijiang, Deyang, Suining, Panzhihua, Liangshan Yi Autonomous Prefecture, Yibin, Zigong, Meishan, Ya'an, Guangyuan, Ziyang, Leshan, Ngawa Tibetan and Qiang Autonomous Prefecture, Shenzhen, Guangzhou, Foshan, Zhongshan, Dongguan, Shantou, Zhuhai, Huizhou, Jiangmen, Zhanjiang, Zhaoqing, Meizhou, Yangjiang, Maoming, Qingyuan, Shaoguan, Jieyang, Shanwei, Chaozhou, Heyuan, Area not defined, Lishui, Hangzhou, Wenzhou, Huzhou, Jiaxing, Shaoxing, Ningbo, Taizhou, Jinhua, Shilifeng Prison, Quzhou, Zhoushan, Chaoyang District, Haidian District, Xicheng District, Fengtai District, Daxing District, People from other cities, Changping District, Tongzhou District, Fangshan District, Dongcheng District, Shijingshan District, Shunyi District, Huairou District, Miyun District, Mentougou District, Yanqing District, Area not defined, Wuhan, Xiaogan, Ezhou, Suizhou, Jingzhou, Huanggang, Yichang, Shiyan, Huangshi, Xiantao, Jingmen, Xiangyang, Enshi Tujia and Miao Autonomous Prefecture, Qianjiang, Tianmen, Xianning, Shennongjia, Harbin, Suihua, Qiqihar, Daqing, Shuangyashan, Heihe, Daxinganling, Jixi, Qitaihe, Jiamusi, Mudanjiang, Hegang, Yichun, Lanzhou, Tianshui, Pingliang, Dingxi, Gannan, Baiyin, Longnan, Qingyang, Linxia, Zhangye, Jinchang, People from other cities, Pudong District, Baoshan District, Jiading District, Xuhui District ...

# %% [markdown]
# Let's come up with a possible infection model..

# %% [markdown]
# # A possible model of infection
#
# This requires version 3.8 of `PyMC3'!

# %%
import pymc3 as pm
pm.__version__
# Out:
# '3.8'

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('seaborn-darkgrid')

# %% [markdown]
# ## Acquired immunity controls the infection
#
# The Susceptible-Infected-Recovered model of infection describes time dynamics of an
# [infectious disease](https://en.wikipedia.org/wiki/Compartmental_models_in_epidemiology) spreading through a homogenous closed population (no births or deaths). The population is divided into three categories: **Susceptible** `S`, **Infective** `I`, or **Recovered/Dead** `R`. We can further refine our model by having a different category `D` for dead, but let's keep it simple for now and include dead people as recovered. When people die, if properly buried, they cannot infect anymore and so they are equivalent to people that have recovered and are immune to the infection.
#
# Susceptible individuals are those that have not acquired immunity yet and are susceptible to becoming infected.
#
# Infected individuals have been infected with the disease.
#
# Recovered individuals are cured and not susceptible anymore to the disease.
#
# >**NOTE**: In China, some people have been described as cured and released from hospitals and yet they test positive again for Covid19 later on. This is actually impossible because if you recover, you *have to be immune* to the disease, and is most likley assocaited with false positives and false negatives (patients where either impoperly labeled as cured, or improperly tested as infected). It is also possible that we are dealing with multiple Covid19 strains, in which case it is possible to become infected with another strain after being cured from one. It may also be possible that the virus mutates so fast that it essentially becomes a different strain in a few days and can reinfect an immune individual. God help us all if that is the case.
#
# [Differential equations](https://en.wikipedia.org/wiki/Ordinary_differential_equation) are a mathematical framework for modelling temporal dynamics of a system. The [differential equations for the SIR model of infection](https://www.maa.org/press/periodicals/loci/joma/the-sir-model-for-spread-of-disease-the-differential-equation-model) are:
#
# $$\dfrac{dS}{dt} = - \beta SI \quad S(0) = S_0$$
#
# $$\dfrac{dI}{dt} = \beta SI - \gamma I \quad I(0) = I_0$$
#
# $$\dfrac{dR}{dt} = \gamma I \quad R(0) = R_0$$
#
# With the constraint that:
#
# $$S(t) + I(t) + R(t) = 1 \;\;, \forall t$$
#
# Other models are available for modeling infectious diseases, such as the [IBM](https://arxiv.org/ftp/arxiv/papers/1902/1902.02784.pdf) model.
#
# If we know R(t) and I(t) then we can determine S(t): $S(t) = 1 - I(t) - R(t)$, so we can work only with the two unknowns: R(t) and I(t). We prefer to work with these because that is what the China Covid19 dataset gives us!
#
# So we write:
#
# $$\dfrac{dI}{dt} = \beta (1 - I - R) I - \gamma I \quad I(0) = I_0$$
#
# $$\dfrac{dR}{dt} = \gamma I \quad R(0) = R_0$$
#
# Simplifying:
#
# $$\dfrac{dI}{dt} = \beta (1 - I - R -\gamma/\beta) I  \quad I(0) = I_0$$
#
# $$\dfrac{dR}{dt} = \gamma I \quad R(0) = R_0$$
#
# We have two equations in two unknowns, so we're good mathematicaly speaking. What are the parameters?
#
# $β$ is the rate of infection per susceptible and per infective individual: $\beta$ is an average infected to non-infected individual contact (e.g. 4 individuals) and hinges on the underlying society. Arguably, it is higher in China where the population is denser. But it also high in very social Mediterranean countries like Italy and Spain. $\gamma$ is the rate of recovery: It can be interpreted as an average period of infectiousness (e.g. 3 to 5 days for the common flu). For Covid19, experts are astonished by how long an individual can infect others and say that it can be up to 30 days!
#
# >For an example, in the Hong Kong flu in New York City in the late 1960's, hardly anyone was immune at the beginning of the epidemic, so almost everyone was susceptible. [This](https://www.maa.org/press/periodicals/loci/joma/the-sir-model-for-spread-of-disease-the-differential-equation-model) paper gives an estimate for the parameters. Assuming a trace level of infection in the population, say, 10 people, population variables are S(0) = 7,900,000, I(0) = 10, R(0) = 0. In terms of scaled variables, these initial conditions are s(0) = 1, i(0) = 1.27 x 10-6, r(0) = 0. We don't know values for the parameters $\beta$ and $\gamma$ yet, but they can be estimated and then adjusted as necessary to fit the excess death data. The average period of infectiousness is estimated at three days, so that would suggest  $\gamma = 1/3$.  *Guessing* that each infected individual would make a possibly infecting contact with another individual every two days, then $\beta$ would be $1/2$. So $\beta/\gamma = 3/2 > 1$.
#
# The quantity $β/γ$ is called [R-Nought](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC1181873/) ($R_0$). Its interpretation is that if we were to drop a *single* infected person into a population of suceptible individuals, we would expect $R_0$ new infections. If $R_0>1$, then an epidemic will take place. If $R_0≤1$ then there will be no epidemic.
#
# >When $R_0<1$, each person who contracts the disease will infect fewer than one person before dying or recovering, so the outbreak will fizzle ($dI/dt<0$). When $R_0>1$, each person who gets the disease will infect more than one person, so the epidemic will spread ($dI/dt>0$). $R_0$ is the most important quantity in epidemiology.
#
# Let's model our SIR equations using a python function. `y` is our unknown, it's 2D: $y[0] = I$ and $y[1] = R$. . The parameters `p` are 2D: $p[0] = \beta$ and $p[1] = \gamma$.

# %%
def SIR(y, t, p):
    di = p[0] * (1. - y[0] - y[1] - p[1]/p[0]) * y[0]
    dr = p[1] * y[0]
    return [di, dr]

# %% [markdown]
# Write down the python function that will yield the suceptible population, given the infected and recovered population:

# %%
def susceptible(i, r):
    return 1-i-r

# %% [markdown]
# This is our time discretization (about 3 months of data by day data):

# %%
import numpy as np
times = np.arange(0, 5, 0.25)

# %% [markdown]
# Let's compute *exact* values for `y` (y\[0\] = I and y\[1\] = R). Let's assume that I(0) = 0.01 and R(0) = 0. In other words, we start with 1% infected individuals in the population, 0 recovered, and so 1 - 0.01 - 0 = 99% susceptible individuals.
#
# Let's pick some values for $\beta$ and $\gamma$ to begin with (we will model them based on China's data leter on), which guarantee an epidemic ($\beta > \gamma$):

# %%
beta, gamma = 4.0, 1.0

# %% [markdown]
# Realistically, an individual may be in infectious contact with more than 4 other individuals per day, and Covid19's infectivity is much bigger than 1 day!
#
# We use the library `odeint` from the package `scipy.integrate` to solve the ordinary differential equations for SIR:

# %%
from scipy.integrate import odeint

# Compute true curves
y = odeint(SIR, t=times, y0=[0.01, 0.0], args=((beta, gamma),), rtol=1e-8)

# %% [markdown]
# The data has uncertainty (or ***noise***) because of our measurement tools ([aleatoric uncertainty](https://en.wikipedia.org/wiki/Uncertainty_quantification)), but also because the modeling equations are ot perfect ([epistemic uncertainity](https://en.wikipedia.org/wiki/Uncertainty_quantification)).
#
# We pick a [log-normal distribution](https://en.wikipedia.org/wiki/Log-normal_distribution), a continuous probability distribution whose logarithm is *normally distributed* (thus, if the random variable X is log-normally distributed, then Y = ln(X) has a normal distribution) as our observations pdf, with a mean equal to the log of `y`.
#
# >**NOTE**: Recall that taking the logarithm of a histogram of a dataset makes the histogram look much prettier (可爱极了), i.e. closer to a normal distribution, so that we can indeed model it as a normal distribution. So this is a very common operation amongst data scientists.
#
# So, these are our observations: Data from the true curves for I and R with errors 10% and 10% respectively

# %%
yobs = np.random.lognormal(mean=np.log(y[1::]), sigma=[0.1, 0.1])
yobs
# Out:
# array([[0.01992078, 0.0040754 ],
#        [0.04106335, 0.01103191],
#        [0.08522973, 0.02854084],
#        [0.17781934, 0.05813881],
#        [0.26375174, 0.13816031],
#        [0.31968177, 0.16818571],
#        [0.39588822, 0.29776879],
#        [0.44044704, 0.35698364],
#        [0.33468607, 0.48510623],
#        [0.31439202, 0.52835852],
#        [0.28001587, 0.61650402],
#        [0.25730999, 0.70707179],
#        [0.17699632, 0.78903944],
#        [0.14403086, 0.71307132],
#        [0.13712528, 0.8530159 ],
#        [0.10127517, 0.78995288],
#        [0.0805125 , 1.04063938],
#        [0.08153943, 0.98978263],
#        [0.05790491, 0.96537742]])

# %% [markdown]
# Now plot our observations as datapoints on top of the exact values for S and I. R is not observed but estimated from the exact curves for S and I. Plot that, too.

# %%
plt.plot(times[1::],yobs, marker='o', linestyle='none')
plt.plot(times, y[:,0], color='C0', alpha=0.5, label=f'$I(t)$')
plt.plot(times, y[:,1], color ='C1', alpha=0.5, label=f'$R(t)$')
plt.plot(times, susceptible(y[:,0], y[:,1]), color ='C2', alpha=0.5, label=f'$S(t)$')
plt.legend()

# %% [markdown]
# This data looks very close to our China data: Driven by rising infections, susceptible population diminishes due to acquired immunity, which controls the infection and brings it down to zero after it reaches a peak of 40% of the population, for the values of the parameters $\beta$ and $\gamma$ that we picked. Very sobering.
#
# Our China data though is only up to timepoint 2. We have *yet* to observe the infection to come down. All we observe in China is that *the number of new infections is coming down to almost zero*, which means we are approaching the peak of the Infected curve $I(t)$.

# %% [markdown]
# # Modeling with China's data
#
# Let's model China's infection data with Bayesian estimation in order to figure out the critical Chinese $\beta$ and $\gamma$ parameters. Based on social comparisons, we can estimate our own $\beta$ parameter, so that will give us a disease $R_0$, which will tell us how *dangerous* Covid19 really is.
#
# >Flyers about how the flu kills more people than Covid19 abounded around campus, and are probably partly responsible for the complacent response to the epidemic in Western societies. Let's see how much *more dangerous* than the flu it really is.
#
# Let's plot Wuhan's infected and cured populations once again:

# %%
wuhan_data["city_curedCount"].plot()
plt.xticks(rotation=90)
plt.show()

# %%
wuhan_data["city_confirmedCount"].plot()
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Extrapolating Chinese data to the fizzling out of the pandemic
#
# We have to complete the Chinese data since it only goes up to the peak. We will assume that what we hear from China is correct: The epidemic has peaked and is petering out, thanks to the draconian quarantine measures undertaken. So let's just mirror out the infected data so that it decreases at the same rate, and let's just continue the progression of the cured curve.
#
# In other words, you are going to extend `DXYArea.csv` so that it looks like the modelled profiles above. You are going to assume that the epidemic is being contained and that the number of infected people will go down to zero like the model above. So you are going to have to essentially *mirror* the **infected** population profile, and *extrapolate* the **recovered** population profile.
#
# You will add dead people to the **recovered** people curve, so that our empirical data will match our model data.
#
# Wuhan was the hardest hit city, so you will do this just for Wuhan data.
#
# Probably the hardest part will be extending the index, so that you go an extra couple of months from the last data in the empirical data, that is where the number of infected people goes down to zero, and the number of recovered people keeps increasing (just do a simple linear interpolation for the recovered people).
#
# Your dataframe should look something like this:

# %%
wuhan_data
# Out:
#                         provinceName provinceEnglishName cityName  \
# updateTime
# 2020-01-24 09:47:38.698          湖北省               Hubei       武汉
# 2020-01-24 09:48:39.253          湖北省               Hubei       武汉
# 2020-01-24 09:49:39.772          湖北省               Hubei       武汉
# 2020-01-24 09:50:40.357          湖北省               Hubei       武汉
# 2020-01-24 11:49:48.584          湖北省               Hubei       武汉
# ...                              ...                 ...      ...
# 2020-03-14 16:54:11.267          湖北省               Hubei       武汉
# 2020-03-14 17:49:06.329          湖北省               Hubei       武汉
# 2020-03-14 17:58:00.660          湖北省               Hubei       武汉
# 2020-03-15 08:49:13.790          湖北省               Hubei       武汉
# 2020-03-15 18:07:03.272          湖北省               Hubei       武汉
#
#                         cityEnglishName  province_confirmedCount  \
# updateTime
# 2020-01-24 09:47:38.698           Wuhan                      549
# 2020-01-24 09:48:39.253           Wuhan                      549
# 2020-01-24 09:49:39.772           Wuhan                      549
# 2020-01-24 09:50:40.357           Wuhan                      549
# 2020-01-24 11:49:48.584           Wuhan                      549
# ...                                 ...                      ...
# 2020-03-14 16:54:11.267           Wuhan                    67790
# 2020-03-14 17:49:06.329           Wuhan                    67790
# 2020-03-14 17:58:00.660           Wuhan                    67790
# 2020-03-15 08:49:13.790           Wuhan                    67794
# 2020-03-15 18:07:03.272           Wuhan                    67794
#
#                          province_curedCount  province_deadCount  \
# updateTime
# 2020-01-24 09:47:38.698                    0                   0
# 2020-01-24 09:48:39.253                    0                   0
# 2020-01-24 09:49:39.772                    0                   0
# 2020-01-24 09:50:40.357                    0                   0
# 2020-01-24 11:49:48.584                    0                   0
# ...                                      ...                 ...
# 2020-03-14 16:54:11.267                52959                3075
# 2020-03-14 17:49:06.329                52962                3075
# 2020-03-14 17:58:00.660                52960                3075
# 2020-03-15 08:49:13.790                54278                3085
# 2020-03-15 18:07:03.272                54288                3085
#
#                          city_confirmedCount  city_curedCount  city_deadCount
# updateTime
# 2020-01-24 09:47:38.698                  495                0               0
# 2020-01-24 09:48:39.253                  495                0               0
# 2020-01-24 09:49:39.772                  495                0               0
# 2020-01-24 09:50:40.357                  495                0               0
# 2020-01-24 11:49:48.584                  495                0               0
# ...                                      ...              ...             ...
# 2020-03-14 16:54:11.267                49995            36467            2446
# 2020-03-14 17:49:06.329                49995            36467            2446
# 2020-03-14 17:58:00.660                49995            36465            2446
# 2020-03-15 08:49:13.790                49995            36465            2446
# 2020-03-15 18:07:03.272                49999            37642            2456
#
# [365 rows x 10 columns]

# %%
covid19_wuhan_extension_1 = pd.DataFrame(wuhan_data["city_confirmedCount"])
covid19_wuhan_extension_2 = pd.DataFrame(wuhan_data["city_deadCount"]+wuhan_data["city_curedCount"])                          ##+wuhan_data["province_deadCount"]+wuhan_data["province_curedCount"])
covid19_wuhan_extension_2.columns = ["city_recoveredCount"]
covid19_wuhan_extension=pd.concat([covid19_wuhan_extension_1,covid19_wuhan_extension_2],axis=1)     
# last_Data=pd.concat([covid19_wuhan_extension_confirmed,extended_city_recovered_count,date_time],axis=1)
covid19_wuhan_extension
# Out:
#                          city_confirmedCount  city_recoveredCount
# updateTime
# 2020-01-24 09:47:38.698                  495                    0
# 2020-01-24 09:48:39.253                  495                    0
# 2020-01-24 09:49:39.772                  495                    0
# 2020-01-24 09:50:40.357                  495                    0
# 2020-01-24 11:49:48.584                  495                    0
# ...                                      ...                  ...
# 2020-03-14 16:54:11.267                49995                38913
# 2020-03-14 17:49:06.329                49995                38913
# 2020-03-14 17:58:00.660                49995                38911
# 2020-03-15 08:49:13.790                49995                38911
# 2020-03-15 18:07:03.272                49999                40098
#
# [365 rows x 2 columns]

# %%
from datetime import datetime
covid19_wuhan_extension.index = [str(x) for x in covid19_wuhan_extension.index]
covid19_wuhan_extension.index = covid19_wuhan_extension.index.map(lambda x: datetime.strptime(x, '%Y-%m-%d %H:%M:%S.%f').replace(second=0))
covid19_wuhan_extension.index = covid19_wuhan_extension.index.map(lambda x: x.replace(microsecond=0))
covid19_wuhan_extension
# Out:
#                      city_confirmedCount  city_recoveredCount
# 2020-01-24 09:47:00                  495                    0
# 2020-01-24 09:48:00                  495                    0
# 2020-01-24 09:49:00                  495                    0
# 2020-01-24 09:50:00                  495                    0
# 2020-01-24 11:49:00                  495                    0
# ...                                  ...                  ...
# 2020-03-14 16:54:00                49995                38913
# 2020-03-14 17:49:00                49995                38913
# 2020-03-14 17:58:00                49995                38911
# 2020-03-15 08:49:00                49995                38911
# 2020-03-15 18:07:00                49999                40098
#
# [365 rows x 2 columns]

# %% [markdown]
# For interpolation, i have reversed the data
# we have data that is increasing, and we have to generate data that is going back to 0
# so i reversed the data and added to the column

# %%
40098-38911
# Out:
# 1187

# %% [markdown]
# # Extending recovered count

# %%
extended_city_recovered_count= [40098 +300+ x*300 for x in range(len(covid19_wuhan_extension.city_recoveredCount))]
extended_city_recovered_count
# Out:
# [40398,
#  40698,
#  40998,
#  41298,
#  41598,
#  41898,
#  42198,
#  42498,
#  42798,
#  43098,
#  43398,
#  43698,
#  43998,
#  44298,
#  44598,
#  44898,
#  45198,
#  45498,
#  45798,
#  46098,
#  46398,
#  46698,
#  46998,
#  47298,
#  47598,
#  47898,
#  48198,
#  48498,
#  48798,
#  49098,
#  49398,
#  49698,
#  49998,
#  50298,
#  50598,
#  50898,
#  51198,
#  51498,
#  51798,
#  52098,
#  52398,
#  52698,
#  52998,
#  53298,
#  53598,
#  53898,
#  54198,
#  54498,
#  54798,
#  55098,
#  55398,
#  55698,
#  55998,
#  56298,
#  56598,
#  56898,
#  57198,
#  57498,
#  57798,
#  58098,
#  58398,
#  58698,
#  58998,
#  59298,
#  59598,
#  59898,
#  60198,
#  60498,
#  60798,
#  61098,
#  61398,
#  61698,
#  61998,
#  62298,
#  62598,
#  62898,
#  63198,
#  63498,
#  63798,
#  64098,
#  64398,
#  64698,
#  64998,
#  65298,
#  65598,
#  65898,
#  66198,
#  66498,
#  66798,
#  67098,
#  67398,
#  67698,
#  67998,
#  68298,
#  68598,
#  68898,
#  69198,
#  69498,
#  69798,
#  70098,
#  70398,
#  70698,
#  70998,
#  71298,
#  71598,
#  71898,
#  72198,
#  72498,
#  72798,
#  73098,
#  73398,
#  73698,
#  73998,
#  74298,
#  74598,
#  74898,
#  75198,
#  75498,
#  75798,
#  76098,
#  76398,
#  76698,
#  76998,
#  77298,
#  77598,
#  77898,
#  78198,
#  78498,
#  78798,
#  79098,
#  79398,
#  79698,
#  79998,
#  80298,
#  80598,
#  80898,
#  81198,
#  81498,
#  81798,
#  82098,
#  82398,
#  82698,
#  82998,
#  83298,
#  83598,
#  83898,
#  84198,
#  84498,
#  84798,
#  85098,
#  85398,
#  85698,
#  85998,
#  86298,
#  86598,
#  86898,
#  87198,
#  87498,
#  87798,
#  88098,
#  88398,
#  88698,
#  88998,
#  89298,
#  89598,
#  89898,
#  90198,
#  90498,
#  90798,
#  91098,
#  91398,
#  91698,
#  91998,
#  92298,
#  92598,
#  92898,
#  93198,
#  93498,
#  93798,
#  94098,
#  94398,
#  94698,
#  94998,
#  95298,
#  95598,
#  95898,
#  96198,
#  96498,
#  96798,
#  97098,
#  97398,
#  97698,
#  97998,
#  98298,
#  98598,
#  98898,
#  99198,
#  99498,
#  99798,
#  100098,
#  100398,
#  100698,
#  100998,
#  101298,
#  101598,
#  101898,
#  102198,
#  102498,
#  102798,
#  103098,
#  103398,
#  103698,
#  103998,
#  104298,
#  104598,
#  104898,
#  105198,
#  105498,
#  105798,
#  106098,
#  106398,
#  106698,
#  106998,
#  107298,
#  107598,
#  107898,
#  108198,
#  108498,
#  108798,
#  109098,
#  109398,
#  109698,
#  109998,
#  110298,
#  110598,
#  110898,
#  111198,
#  111498,
#  111798,
#  112098,
#  112398,
#  112698,
#  112998,
#  113298,
#  113598,
#  113898,
#  114198,
#  114498,
#  114798,
#  115098,
#  115398,
#  115698,
#  115998,
#  116298,
#  116598,
#  116898,
#  117198,
#  117498,
#  117798,
#  118098,
#  118398,
#  118698,
#  118998,
#  119298,
#  119598,
#  119898,
#  120198,
#  120498,
#  120798,
#  121098,
#  121398,
#  121698,
#  121998,
#  122298,
#  122598,
#  122898,
#  123198,
#  123498,
#  123798,
#  124098,
#  124398,
#  124698,
#  124998,
#  125298,
#  125598,
#  125898,
#  126198,
#  126498,
#  126798,
#  127098,
#  127398,
#  127698,
#  127998,
#  128298,
#  128598,
#  128898,
#  129198,
#  129498,
#  129798,
#  130098,
#  130398,
#  130698,
#  130998,
#  131298,
#  131598,
#  131898,
#  132198,
#  132498,
#  132798,
#  133098,
#  133398,
#  133698,
#  133998,
#  134298,
#  134598,
#  134898,
#  135198,
#  135498,
#  135798,
#  136098,
#  136398,
#  136698,
#  136998,
#  137298,
#  137598,
#  137898,
#  138198,
#  138498,
#  138798,
#  139098,
#  139398,
#  139698,
#  139998,
#  140298,
#  140598,
#  140898,
#  141198,
#  141498,
#  141798,
#  142098,
#  142398,
#  142698,
#  142998,
#  143298,
#  143598,
#  143898,
#  144198,
#  144498,
#  144798,
#  145098,
#  145398,
#  145698,
#  145998,
#  146298,
#  146598,
#  146898,
#  147198,
#  147498,
#  147798,
#  148098,
#  148398,
#  148698,
#  148998,
#  149298,
#  149598]

# %%
extended_city_recovered_count= pd.DataFrame(extended_city_recovered_count)
extended_city_recovered_count.columns=["city_recoveredCount"]
extended_city_recovered_count
# Out:
#      city_recoveredCount
# 0                  40398
# 1                  40698
# 2                  40998
# 3                  41298
# 4                  41598
# ..                   ...
# 360               148398
# 361               148698
# 362               148998
# 363               149298
# 364               149598
#
# [365 rows x 1 columns]

# %% [markdown]
# # Extending Dates

# %%
from datetime import datetime
from dateutil.relativedelta import relativedelta

extended_3months = [x + relativedelta(months=1, days=21) for x in covid19_wuhan_extension.index]
date_time=pd.DataFrame(extended_3months)
date_time.columns=["updateTime"]
date_time
# Out:
#              updateTime
# 0   2020-03-16 09:47:00
# 1   2020-03-16 09:48:00
# 2   2020-03-16 09:49:00
# 3   2020-03-16 09:50:00
# 4   2020-03-16 11:49:00
# ..                  ...
# 360 2020-05-05 16:54:00
# 361 2020-05-05 17:49:00
# 362 2020-05-05 17:58:00
# 363 2020-05-06 08:49:00
# 364 2020-05-06 18:07:00
#
# [365 rows x 1 columns]

# %% [markdown]
# # Extending confirmed count

# %%
covid19_wuhan_extension_confirmed = pd.DataFrame(wuhan_data["city_confirmedCount"])                         
covid19_wuhan_extension_confirmed.columns = ["city_confirmedCount"]
covid19_wuhan_extension_confirmed
# Out:
#                          city_confirmedCount
# updateTime
# 2020-01-24 09:47:38.698                  495
# 2020-01-24 09:48:39.253                  495
# 2020-01-24 09:49:39.772                  495
# 2020-01-24 09:50:40.357                  495
# 2020-01-24 11:49:48.584                  495
# ...                                      ...
# 2020-03-14 16:54:11.267                49995
# 2020-03-14 17:49:06.329                49995
# 2020-03-14 17:58:00.660                49995
# 2020-03-15 08:49:13.790                49995
# 2020-03-15 18:07:03.272                49999
#
# [365 rows x 1 columns]

# %%
covid19_wuhan_extension_confirmed = covid19_wuhan_extension_confirmed[::-1]
covid19_wuhan_extension_confirmed
# Out:
#                          city_confirmedCount
# updateTime
# 2020-03-15 18:07:03.272                49999
# 2020-03-15 08:49:13.790                49995
# 2020-03-14 17:58:00.660                49995
# 2020-03-14 17:49:06.329                49995
# 2020-03-14 16:54:11.267                49995
# ...                                      ...
# 2020-01-24 11:49:48.584                  495
# 2020-01-24 09:50:40.357                  495
# 2020-01-24 09:49:39.772                  495
# 2020-01-24 09:48:39.253                  495
# 2020-01-24 09:47:38.698                  495
#
# [365 rows x 1 columns]

# %%
covid19_wuhan_extension_confirmed = covid19_wuhan_extension_confirmed.reset_index()
covid19_wuhan_extension_confirmed = covid19_wuhan_extension_confirmed.drop(['updateTime'],axis=1)
covid19_wuhan_extension_confirmed
# Out:
#      city_confirmedCount
# 0                  49999
# 1                  49995
# 2                  49995
# 3                  49995
# 4                  49995
# ..                   ...
# 360                  495
# 361                  495
# 362                  495
# 363                  495
# 364                  495
#
# [365 rows x 1 columns]

# %%
last_Data=pd.concat([covid19_wuhan_extension_confirmed,extended_city_recovered_count,date_time],axis=1)
last_Data=last_Data.set_index('updateTime')
last_Data
# Out:
#                      city_confirmedCount  city_recoveredCount
# updateTime
# 2020-03-16 09:47:00                49999                40398
# 2020-03-16 09:48:00                49995                40698
# 2020-03-16 09:49:00                49995                40998
# 2020-03-16 09:50:00                49995                41298
# 2020-03-16 11:49:00                49995                41598
# ...                                  ...                  ...
# 2020-05-05 16:54:00                  495               148398
# 2020-05-05 17:49:00                  495               148698
# 2020-05-05 17:58:00                  495               148998
# 2020-05-06 08:49:00                  495               149298
# 2020-05-06 18:07:00                  495               149598
#
# [365 rows x 2 columns]

# %%
covid19_wuhan_data=covid19_wuhan_extension.append(last_Data)
covid19_wuhan_data
# Out:
#                      city_confirmedCount  city_recoveredCount
# 2020-01-24 09:47:00                  495                    0
# 2020-01-24 09:48:00                  495                    0
# 2020-01-24 09:49:00                  495                    0
# 2020-01-24 09:50:00                  495                    0
# 2020-01-24 11:49:00                  495                    0
# ...                                  ...                  ...
# 2020-05-05 16:54:00                  495               148398
# 2020-05-05 17:49:00                  495               148698
# 2020-05-05 17:58:00                  495               148998
# 2020-05-06 08:49:00                  495               149298
# 2020-05-06 18:07:00                  495               149598
#
# [730 rows x 2 columns]

# %% [markdown]
# And the plot something like this:

# %%
plt.plot(covid19_wuhan_data.city_confirmedCount)
plt.plot(covid19_wuhan_data.city_recoveredCount)

plt.title('Covid19 in Wuhan, diagnosed/recovered extrapolated')
plt.ylabel('diagnosed/recovered')
plt.xlabel('Date')
plt.grid(True)

# %% [markdown]
# You can then reduce the size of our data by an order of magnitude:

# %%
covid19_wuhan_extension3 = covid19_wuhan_data[::39]  
len(covid19_wuhan_extension3)
# Out:
# 19

# %%
covid19_wuhan_extension3
# Out:
#                      city_confirmedCount  city_recoveredCount
# 2020-01-24 09:47:00                  495                    0
# 2020-01-27 16:42:00                  698                  105
# 2020-02-02 11:07:00                 4109                  362
# 2020-02-06 14:26:00                10117                  846
# 2020-02-08 17:10:00                13603                 1292
# 2020-02-13 00:19:00                19558                 2200
# 2020-02-19 13:52:00                44412                 6409
# 2020-02-23 20:06:00                46201                10045
# 2020-03-01 18:06:00                49122                21771
# 2020-03-10 23:01:00                49965                34379
# 2020-03-18 09:53:00                49948                47898
# 2020-03-22 08:23:00                47824                59598
# 2020-03-25 17:34:00                45660                71298
# 2020-03-28 20:00:00                41152                82998
# 2020-03-31 17:26:00                16902                94698
# 2020-04-07 12:34:00                11618               106398
# 2020-04-12 09:47:00                 8351               118098
# 2020-04-17 18:14:00                 3215               129798
# 2020-04-29 20:44:00                  618               141498

# %%
plt.plot(covid19_wuhan_extension3.city_confirmedCount)
plt.plot(covid19_wuhan_extension3.city_recoveredCount)

plt.title('Covid19 in Wuhan, diagnosed/recovered extrapolated, thinned out')
plt.ylabel('diagnosed/recovered')
plt.xlabel('Date')
plt.grid(True)

# %% [markdown]
# and renormalize so that all values are less than 1, with the number of recovered people slowly reaching 100%.

# %%
from sklearn import preprocessing
x= covid19_wuhan_extension3.values
minMaxScalar= preprocessing.MinMaxScaler()
scaled= minMaxScalar.fit_transform(x)
covid19_wuhan_extension4=pd.DataFrame(scaled)

# %%
plt.plot(covid19_wuhan_extension4)
plt.title('Covid19 in Wuhan, diagnosed/recovered extrapolated, thinned out')
plt.ylabel('diagnosed/recovered')
plt.xlabel('Date')
plt.grid(True)

# %% [markdown]
# How to extrapolate the recovered curve?
#
# Since we're looking for an upper bound for $R_0$, let's make the naive assumption that 140,000 is the population of Wuhan that is susceptible to the virus (137233 is the max of the recovered column). This is most probably not true, since the population of the city of Wuhan, the 9th most populous Chinese city, is closer to 11 million. But probably not the entirety of that number is as exposed as the city center. I think the urban city center (9 million) may be a more appropriate statistic.

# %%
covid19_wuhan_extension_4=covid19_wuhan_extension3.div(145000)
covid19_wuhan_extension_4
# Out:
#                      city_confirmedCount  city_recoveredCount
# 2020-01-24 09:47:00             0.003414             0.000000
# 2020-01-27 16:42:00             0.004814             0.000724
# 2020-02-02 11:07:00             0.028338             0.002497
# 2020-02-06 14:26:00             0.069772             0.005834
# 2020-02-08 17:10:00             0.093814             0.008910
# 2020-02-13 00:19:00             0.134883             0.015172
# 2020-02-19 13:52:00             0.306290             0.044200
# 2020-02-23 20:06:00             0.318628             0.069276
# 2020-03-01 18:06:00             0.338772             0.150145
# 2020-03-10 23:01:00             0.344586             0.237097
# 2020-03-18 09:53:00             0.344469             0.330331
# 2020-03-22 08:23:00             0.329821             0.411021
# 2020-03-25 17:34:00             0.314897             0.491710
# 2020-03-28 20:00:00             0.283807             0.572400
# 2020-03-31 17:26:00             0.116566             0.653090
# 2020-04-07 12:34:00             0.080124             0.733779
# 2020-04-12 09:47:00             0.057593             0.814469
# 2020-04-17 18:14:00             0.022172             0.895159
# 2020-04-29 20:44:00             0.004262             0.975848

# %%
plt.plot(covid19_wuhan_extension_4)
plt.title('Covid19 in Wuhan, diagnosed/recovered extrapolated, thinned out')
plt.ylabel('diagnosed/recovered')
plt.xlabel('Date')
plt.grid(True)

# %%
y_wuhan4=covid19_wuhan_extension_4.to_numpy()
y_wuhan4[1,1] = 0.001
y_wuhan4[0,1] = 0.001
y_wuhan4
# Out:
# array([[0.00341379, 0.001     ],
#        [0.00481379, 0.001     ],
#        [0.02833793, 0.00249655],
#        [0.06977241, 0.00583448],
#        [0.09381379, 0.00891034],
#        [0.13488276, 0.01517241],
#        [0.30628966, 0.0442    ],
#        [0.31862759, 0.06927586],
#        [0.33877241, 0.15014483],
#        [0.34458621, 0.23709655],
#        [0.34446897, 0.33033103],
#        [0.32982069, 0.41102069],
#        [0.31489655, 0.49171034],
#        [0.2838069 , 0.5724    ],
#        [0.11656552, 0.65308966],
#        [0.08012414, 0.73377931],
#        [0.0575931 , 0.81446897],
#        [0.02217241, 0.89515862],
#        [0.00426207, 0.97584828]])

# %%
yobs
# Out:
# array([[0.01992078, 0.0040754 ],
#        [0.04106335, 0.01103191],
#        [0.08522973, 0.02854084],
#        [0.17781934, 0.05813881],
#        [0.26375174, 0.13816031],
#        [0.31968177, 0.16818571],
#        [0.39588822, 0.29776879],
#        [0.44044704, 0.35698364],
#        [0.33468607, 0.48510623],
#        [0.31439202, 0.52835852],
#        [0.28001587, 0.61650402],
#        [0.25730999, 0.70707179],
#        [0.17699632, 0.78903944],
#        [0.14403086, 0.71307132],
#        [0.13712528, 0.8530159 ],
#        [0.10127517, 0.78995288],
#        [0.0805125 , 1.04063938],
#        [0.08153943, 0.98978263],
#        [0.05790491, 0.96537742]])

# %%
yobs.shape
# Out:
# (19, 2)

# %%
y_wuhan4.shape
# Out:
# (19, 2)

# %% [markdown]
# Now we have our data, we are ready for our Bayesian modeling!

# %% [markdown]
# ### Bayesian modeling Chinese stats

# %% [markdown]
# We import `DifferentialEquation` from `PyMC3`:

# %%
import numpy as np
import pymc3 as pm
from pymc3.ode import DifferentialEquation
import theano

# %% [markdown]
# Matching shapes for X and Y:

# %%
np.arange(0.25, 5, 0.00662).shape
# Out:
# (718,)

# %% [markdown]
# Our epidemic model dynamics are captured thusly:

# %%
sir_model = DifferentialEquation(
    func = SIR,
    times = np.arange(0.25, 5, 0.2),
    n_states = 2,
    n_theta = 2,
    t0 = 0,
)

# %% [markdown]
# We will model observations with a [log-normal distribution](https://en.wikipedia.org/wiki/Log-normal_distribution), a continuous probability density function (pdf) whose logarithm is normally distributed. Thus, if the random variable X is log-normally distributed, then Y = ln(X) has a normal distribution.
#
# Taking the logarithm of a dataset is a big-time prettyfier of data and is often a first target model. So we will assume that our Chinese I (infected) and R (recovered) data are log-normally distributed. We will add dead people to the recovered population since that is how we built our infectious model above.
#
# We will assume that there is noise/error in the Chinese data, so we will tack on a standard deviation. Since that quantity is never negative, it is often modelled as a Half [Cauchy](https://en.wikipedia.org/wiki/Cauchy_distribution) distribution. It has an interesting history.
#
# >**NOTE**: The half-Cauchy is heavy tailed and is regarded as fairly weakly informative. Gelman advocates for half-t priors (including the half-Cauchy) because they have better behavior for small parameter values but only regards it as weakly informative when a large scale parameter is used. See [A. Gelman (2006),
# "Prior distributions for variance parameters in hierarchical models"
# Bayesian Analysis, Vol. 1, N. 3, pp. 515–533](http://www.stat.columbia.edu/~gelman/research/published/taumain.pdf).
#
# <br />
# <center>
# <img src="ipynb.images/half-cauchy.png" width=600 />
# </center>
#
# To model the parameters themselves, we will assume a very uninformative $R_0$ that is just $> 1$ so that we have an epidemic, a $\gamma$ that also follows a log-normal distribution (so we only use one pdf type for our model, but hey, *you're free to try another one*!), and a $\beta$ that is deterministically given by $\gamma * R_0$.
#
# The data whose likelihood we're trying to model is given by the `sir_model` above: our function `SIR` given even further above, a time discretization from 0.25 to 5, starting from time 0, with 2D data (I, R) for Wuhan, Hubei, and 2D parameters (`R0` and `gama`). We pick Wuhan because it gives us the worst possible case since it's the epicenter of the disease.
#
# So, sigma (`sig`) is a half-Cuachy:
# ```(python)
# sig = pm.HalfCauchy('sig', 1, shape=2)s
# ```
#
# $R_0$ is another model parameter, which we bound below by 1 (>1) because an epidemic has occured!
# ```(python)
# R0 = pm.Bound(pm.Normal, lower=1)('R0', 2, 3)
# ```
#
# We model $\gamma$ with the same pdf as the data likelihood:
# ```(python)
# gama = pm.Lognormal('gama', pm.math.log(2), 2)
# ```
#
# And so 4\beta$ is given deterministically by:
# ```(python)
# beta = pm.Deterministic('beta', gama*R0)
# ```
#
# Then we model the data likelihood thusly:
# ```(python)
# sir_curves = sir_model(y0=[0.01, 0.0], theta=[beta, gama])
# Y = pm.Lognormal('Y', mu=pm.math.log(sir_curves), sd=sig, observed=y_wuhan4)
# ```
#
# Try setting the prior to this:
# ```(python)
# prior = pm.sample_prior_predictive()
# ```
#
# And finally run your NUTS sim (you may want to start with a Metropolis sim):
# ```(python)
# trace = pm.sample(2000, tune=1000, target_accept=0.9, cores=1)
# ```

# %%
pm.math.log(sir_curves)
# Out:
# Elemwise{log,no_inplace}.0

# %%
sigma
# Out:
# sigma

# %% [markdown]
# Testing!!!

# %%
import arviz as az
import pymc3 as pm

with pm.Model() as model:
    sigma = pm.HalfCauchy('sigma', 1, shape=2)

    # R0 is bounded below by 1 because we see an epidemic has occured
    R0 = pm.Bound(pm.Normal, lower=1)('R0', 2, 3)
    gama = pm.Lognormal('gama', pm.math.log(2), 2)
    beta = pm.Deterministic('beta', gama*R0)

    sir_curves = sir_model(y0=[0.01, 0.0], theta=[beta, gama])

    # data likelihood
    Y = pm.Lognormal('Y', mu=pm.math.log(sir_curves), sd=sigma, observed=yobs)

    prior = pm.sample_prior_predictive()
    trace = pm.sample(2000, tune=1000, target_accept=0.9, cores=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-110-1eb92ab7a8ae> in <module>
#      14     # data likelihood
#      15     #Y = pm.Lognormal('Y', mu=pm.math.log(sir_curves), sd=sigma, observed=y_wuhan4)
# ---> 16     Y = pm.Lognormal('Y', mu=pm.math.log(sir_curves), sd=sigma, observed=yobs)
#      17
#      18     prior = pm.sample_prior_predictive()
#
# ~\Anaconda3\lib\site-packages\pymc3\distributions\distribution.py in __new__(cls, name, *args, **kwargs)
#      45             total_size = kwargs.pop('total_size', None)
#      46             dist = cls.dist(*args, **kwargs)
# ---> 47             return model.Var(name, dist, data, total_size)
#      48         else:
#      49             raise TypeError("Name needs to be a string but got: {}".format(name))
#
# ~\Anaconda3\lib\site-packages\pymc3\model.py in Var(self, name, dist, data, total_size)
#     950                 var = ObservedRV(name=name, data=data,
#     951                                  distribution=dist,
# --> 952                                  total_size=total_size, model=self)
#     953             self.observed_RVs.append(var)
#     954             if var.missing_values:
#
# ~\Anaconda3\lib\site-packages\pymc3\model.py in __init__(self, type, owner, index, name, data, distribution, total_size, model)
#    1486
#    1487             self.missing_values = data.missing_values
# -> 1488             self.logp_elemwiset = distribution.logp(data)
#    1489             # The logp might need scaling in minibatches.
#    1490             # This is done in `Factor`.
#
# ~\Anaconda3\lib\site-packages\pymc3\distributions\continuous.py in logp(self, value)
#    1834         return bound(-0.5 * tau * (tt.log(value) - mu)**2
#    1835                      + 0.5 * tt.log(tau / (2. * np.pi))
# -> 1836                      - tt.log(value),
#    1837                      tau > 0)
#    1838
#
# ~\Anaconda3\lib\site-packages\theano\tensor\var.py in __sub__(self, other)
#     145         # and the return value in that case
#     146         try:
# --> 147             return theano.tensor.basic.sub(self, other)
#     148         except (NotImplementedError, AsTensorError):
#     149             return NotImplemented
#
# ~\Anaconda3\lib\site-packages\theano\gof\op.py in __call__(self, *inputs, **kwargs)
#     672                 thunk.outputs = [storage_map[v] for v in node.outputs]
#     673
# --> 674                 required = thunk()
#     675                 assert not required  # We provided all inputs
#     676
#
# ~\Anaconda3\lib\site-packages\theano\gof\op.py in rval(p, i, o, n)
#     890             # default arguments are stored in the closure of `rval`
#     891             def rval(p=p, i=node_input_storage, o=node_output_storage, n=node):
# --> 892                 r = p(n, [x[0] for x in i], o)
#     893                 for o in node.outputs:
#     894                     compute_map[o][0] = True
#
# ~\Anaconda3\lib\site-packages\theano\tensor\elemwise.py in perform(self, node, inputs, output_storage)
#     788             nout = ufunc.nout
#     789
# --> 790         variables = ufunc(*ufunc_args, **ufunc_kwargs)
#     791
#     792         if nout == 1:
#
# ValueError: operands could not be broadcast together with shapes (19,2) (24,2)

# %% [markdown]
# Now doing with Wuhan Data

# %%
with pm.Model() as model7:
    sigma = pm.HalfCauchy('sigma', 1, shape=2)

    # R0 is bounded below by 1 because we see an epidemic has occured
    R0 = pm.Bound(pm.Normal, lower=1)('R0', 2, 3)
    gama = pm.Lognormal('gama', pm.math.log(2), 2)
    beta = pm.Deterministic('beta', gama*R0)

    sir_curves = sir_model(y0=[0.01, 0.0], theta=[beta, gama])

    # data likelihood
    Y = pm.Lognormal('Y', mu=pm.math.log(sir_curves), sd=sigma, observed=y_wuhan4)

    prior = pm.sample_prior_predictive()
    trace2 = pm.sample(2000, tune=1000, target_accept=0.9, cores=1)

# %%
with model7:
    posterior_predictive2 = pm.sample_posterior_predictive(trace2)

# %%
import arviz as az

with model7:
    data2 = az.from_pymc3(trace=trace2, prior=prior, posterior_predictive=posterior_predictive2)

# %%
az.plot_posterior(data2, round_to=2, credible_interval=0.95)

# %% [markdown]
# # Conclusion
#
# Estimate the value of $R_0$ for the Coronavirus.
#
# This is some real data science, not just an easy midterm. So try to do as much of the pandas preprocessing in class, and maybe try to finish the Bayesian modeling at home. Do as much as you can!
#
# Good luck, data scientist! You may save the world one day, with yor modeling and predictions. God knows how dearly we need modeling these days, with global warming and all kinds of possible disasters.
#
# Science would not be possible without brave souls, like Li Wenliang, for whom saving his patients was more important than political propaganda. May he be a model for all of us.

# %% [markdown]
# References
# The SIR Model for Spread of Disease - The Differential Equation Model, David Smith, Lang Moore, 2004
#
# Appropriate Models for the Management of Infectious Diseases, Helen J Wearing, Pejman Rohani, Matt J Keeling, 2005
#
# Power-Law Models for Infectious Disease Spread, Sebastian Meyer and Leonhard Held, 2014
#
# The Effect of Disease-Induced Mortality on Structural Network Properties, Lazaros K. Gallos, Nina H. Fefferman, 2015
#
# Fitting Epidemic Models to Data, James Holland Jones, 2018
#
# Direct likelihood-based inference for discretely observed stochastic compartmental models of infectious disease, Lam Si Tung Ho, Forrest W. Crawford, Marc A. Suchard, 2018
#
# Modeling and inference for infectious disease dynamics: a likelihood-based approach, Carles Bretó, 2018
#
# Profile likelihood-based analyses of infectious disease models, Christian Tönsing, Jens Timmer, Clemens Kreutz, 2018, also here
#
# Model selection and parameter estimation for dynamic epidemic models via iterated filtering: application to rotavirus in Germany, Theresa Stocks, Tom Britton, Michael Höhle, 2018
#
# Parameterizing Spatial Models of Infectious Disease Transmission that Incorporate Infection Time Uncertainty Using Sampling-Based Likelihood Approximations, Rajat Malik, Rob Deardon, Grace P. S. Kwong, 2018
#
# A Survey of the Individual-Based Model applied in Biomedical and Epidemiology Research, Erivelton G Nepomuceno1, Denise F Resende1, Márcio J Lacerda1, 2018
#
# Dimitri Pananos blog post on novel PyMC3 functionality
#
# Covid-19 — Navigating the Uncharted, Anthony S. Fauci, M.D., H. Clifford Lane, M.D., and Robert R. Redfield, M.D, 2020
#
# and remember..
